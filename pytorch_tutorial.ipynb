# %%
# import os
# print(os.path())
# %run pythorch.py
# Out:
# tensor([1.], requires_grad=True)
#  tensor([1.])
# predict (before training) 4 4.0
# 	grad: 1.0 2.0 -2.0
# 	grad: 2.0 4.0 -7.920000076293945
# 	grad: 3.0 6.0 -17.107200622558594
# progress: 0 8.129342079162598
# 	grad: 1.0 2.0 -1.7297279834747314
# 	grad: 2.0 4.0 -6.849722862243652
# 	grad: 3.0 6.0 -14.795402526855469
# progress: 1 6.080665111541748
# 	grad: 1.0 2.0 -1.4959795475006104
# 	grad: 2.0 4.0 -5.924078941345215
# 	grad: 3.0 6.0 -12.796010971069336
# progress: 2 4.548274993896484
# 	grad: 1.0 2.0 -1.293818712234497
# 	grad: 2.0 4.0 -5.12352180480957
# 	grad: 3.0 6.0 -11.066808700561523
# progress: 3 3.4020626544952393
# 	grad: 1.0 2.0 -1.1189770698547363
# 	grad: 2.0 4.0 -4.431149482727051
# 	grad: 3.0 6.0 -9.571283340454102
# progress: 4 2.5447072982788086
# 	grad: 1.0 2.0 -0.9677629470825195
# 	grad: 2.0 4.0 -3.832341194152832
# 	grad: 3.0 6.0 -8.277857780456543
# progress: 5 1.9034147262573242
# 	grad: 1.0 2.0 -0.8369832038879395
# 	grad: 2.0 4.0 -3.314453125
# ...
